# %%
#/Volumes/workspace/default/cpg 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

print('CPG demo - Multiple Linear Rergession model')
# %pip install pandas sqlalchemy
# %pip install hdbcli

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# sklearn --> scikit-learn  / package 
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
#df3 = pd.read_sql("SELECT * FROM workspace.default.cpg_dataset_final_agi", con=conn)

df4 = pd.read_csv("/Volumes/workspace/default/cpg/1DATATHON_FINAL_DATASET_PROMO_3c.csv", sep=',')

#from hdbcli import dbapi
#conn = dbapi.connect(
#    address="<hostname>",
#    port=3<NN>MM,
#    user="<username>",
#    password="<password>"
#)
#cursor = conn.cursor()

#query = 'SELECT * FROM CPG_PROMO_AI_TEST_AGIS'
#df4 = pd.read_sql(query, conn)

# df4 = spark.table("CPG_PROMO_AI_TEST_AGIS").toPandas()
# datasourse : SEAMLESS PLANNING : TABLE / CPG_PROMO_AI_TEST_AGIS 

print(df4)
df4.describe()
# 4th model with feature engineering
X = df4.iloc[:,df4.columns != 'VOLUME_OF_SALES']
Y = df4.iloc[:, 0]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state= 0)
print(X)

model4 = linear_model.LinearRegression()

#model.fit(X_train, Y_train)
model4.fit(X, Y)

coeff_df4 = pd.DataFrame(model4.coef_, X.columns, columns=['Coefficient'])
print(coeff_df4)
y_pred = model4.predict(X)

df44 = pd.DataFrame({'Actual': Y, 'Predicted': y_pred})
print(df44.head(20))
model4.score(X, Y)

plt.plot(df44)  # Plot the chart
plt.show()  # display

# %%
# %pip install pandas
